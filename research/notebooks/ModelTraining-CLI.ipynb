# %%
# Clone the repo
# !git clone https://github.com/atikul-islam-sajib/U-Net.git
# Out:
# Cloning into 'U-Net'...
# remote: Enumerating objects: 2019, done.
# remote: Counting objects: 100% (424/424), done.
# remote: Compressing objects: 100% (316/316), done.
# remote: Total 2019 (delta 173), reused 331 (delta 82), pack-reused 1595
# Receiving objects: 100% (2019/2019), 201.31 MiB | 21.39 MiB/s, done.
# Resolving deltas: 100% (287/287), done.

# %%
# Change the directory
# %cd /content/U-Net
# Out:
# /content/U-Net

# %%
# Check the CLI option
# !python /content/U-Net/src/cli.py --help
# Out:
# usage: cli.py [-h] [--image_path IMAGE_PATH] [--batch_size BATCH_SIZE]
#               [--smooth_value SMOOTH_VALUE] [--epochs EPOCHS] [--learning_rate LEARNING_RATE]
#               [--beta1 BETA1] [--beta2 BETA2] [--device DEVICE] [--l2 L2] [--criterion CRITERION]
#               [--display DISPLAY] [--samples {10,20}] [--train] [--test]
#
# Define The Cli Coding For U-Net
#
# options:
#   -h, --help            show this help message and exit
#   --image_path IMAGE_PATH
#                         Path to the image folder
#   --batch_size BATCH_SIZE
#                         Batch size for the dataloader
#   --smooth_value SMOOTH_VALUE
#                         Define the smooth value
#   --epochs EPOCHS       Define the number of epochs
#   --learning_rate LEARNING_RATE
#                         Define the learning rate
#   --beta1 BETA1         Define the beta1 value
#   --beta2 BETA2         Define the beta2 value
#   --device DEVICE       Define the device
# ...

# %%
# Run the training CLI
# !python /content/U-Net/src/cli.py --image_path /content/semantic.zip --batch_size 4 --device cuda\
                                  --smooth_value 0.01 --epochs 100 --learning_rate 0.0002 --display False --train
# Out:
# Epoch: 0, Train Loss: 1.712544725759186, Val Loss: 1.277224292189388
# Epoch: 1, Train Loss: 1.0253052393885425, Val Loss: 0.8359890721612058
# Epoch: 2, Train Loss: 0.6847312583105407, Val Loss: 0.5554751597218595
# Epoch: 3, Train Loss: 0.4540813650092939, Val Loss: 0.3789744543827186
# Epoch: 4, Train Loss: 0.3142034213473327, Val Loss: 0.2941100246320337
# Epoch: 5, Train Loss: 0.22266942872087994, Val Loss: 0.17735923435617934
# Epoch: 6, Train Loss: 0.14965376409958628, Val Loss: 0.12625594835696838
# Epoch: 7, Train Loss: 0.10620744490420725, Val Loss: 0.07543275909403623
# Epoch: 8, Train Loss: 0.06733432894275476, Val Loss: 0.09256484828321106
# Epoch: 9, Train Loss: 0.04029855736995279, Val Loss: 0.07348422033680697
# Epoch: 10, Train Loss: 0.017590725737501506, Val Loss: 0.01203277344831218
# Epoch: 11, Train Loss: -0.0032851373093596994, Val Loss: -0.017833823917514518
# Epoch: 12, Train Loss: -0.021048355988655103, Val Loss: -0.03438196179725356
# ...

# %%
# !python /content/U-Net/src/cli.py --samples 20 --device cuda --test
# Out:
# /content/U-Net/src/test.py:105: RuntimeWarning: invalid value encountered in divide
#   mask = (mask - mask.min()) / (mask.max() - mask.min())
# Figure(2000x1500)
# Figure(640x480)

# %%
from IPython.display import Image

# %%
Image("/content/U-Net/outputs/test_images/result.png")

# %%
Image("/content/U-Net/outputs/test_images/loss.png")
